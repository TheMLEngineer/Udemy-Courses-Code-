# %%
import pandas as pd

# %%
df1 = pd.DataFrame([[1,2,3] , [4,5,6]] ,columns= ['Hi' , 'Hello' , 'World'] , index = ['index1' , 'index2'])

# %%
df1
# Out:
#         Hi  Hello  World
# index1   1      2      3
# index2   4      5      6

# %%
df2 = pd.DataFrame([
    {'Name' : 'Karthik'} , 
    {'Name' : 'Muthu'}
])

# %%
df2
# Out:
#       Name
# 0  Karthik
# 1    Muthu

# %%
dir(df1)
# Out:
# ['Hello',
#  'Hi',
#  'T',
#  'World',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
# ...

# %%
df1.mean()
# Out:
# Hi       2.5
# Hello    3.5
# World    4.5
# dtype: float64

# %%
df1.mean().mean()
# Out:
# 3.5

# %%
from IPython.display import Image

# %%
# How to open Ipython Command line in Anaconda prompt
Image('ipython.png')

# %%
ls
# Out:
#  Volume in drive C is OSDisk
#  Volume Serial Number is 1A6C-69AB
#
#  Directory of C:\Users\kmuthu2\Documents\Udemy\Python Build 10 apps Mega Course
#
# 05/10/2020  12:37 PM    <DIR>          .
# 05/10/2020  12:37 PM    <DIR>          ..
# 05/10/2020  12:02 PM    <DIR>          .ipynb_checkpoints
# 05/08/2020  02:11 PM           207,203 App 1 English Dictionary.ipynb
# 05/08/2020  01:16 PM               801 app1.py
# 07/27/2017  11:22 AM         4,912,995 data.json
# 05/08/2020  12:04 PM         1,464,754 Extract+me.zip
# 05/08/2020  12:03 PM             2,469 Extract-me.zip
# 05/10/2020  12:23 PM            11,944 ipython.png
# 05/10/2020  12:24 PM            37,297 Pandas.ipynb
# 05/10/2020  11:51 AM         5,049,982 Python and MySQL.ipynb
# 05/08/2020  10:45 AM            10,842 Section 2.ipynb
# 05/10/2020  10:52 AM               448 source SQL app.py
# 05/08/2020  02:09 PM               448 source.py
# 05/10/2020  11:02 AM           187,442 sql_fetch.png
# ...

# %%
df1 = pd.read_csv('supermarkets.csv')
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2 = pd.read_json('supermarkets.json')
df2
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2 = pd.read_csv('supermarkets.csv' , header = None)
df2
# Out:
#     0                1              2                 3        4            5  \
# 0  ID          Address           City             State  Country         Name
# 1   1     3666 21st St  San Francisco          CA 94114      USA      Madeira
# 2   2   735 Dolores St  San Francisco          CA 94119      USA  Bready Shop
# 3   3      332 Hill St  San Francisco  California 94114      USA  Super River
# 4   4     3995 23rd St  San Francisco          CA 94114      USA   Ben's Shop
# 5   5  1056 Sanchez St  San Francisco        California      USA      Sanchez
# 6   6  551 Alvarado St  San Francisco          CA 94114      USA   Richvalley
#
#            6
# 0  Employees
# 1          8
# 2         15
# 3         25
# 4         10
# 5         12
# 6         20

# %%
df3 = pd.read_excel('supermarkets.xlsx' , sheet_name=0)
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
pd.read_clipboard()
# Out:
#                                                                                    ID,Address,City,State,Country,Name,Employees
# 1,3666 21st     St,San Francisco,CA                        94114,USA,                                                 Madeira,8
# 2,735  Dolores  St,San Francisco,CA                        94119,USA,Bready                                             Shop,15
# 3,332  Hill     St,San Francisco,California                94114,USA,Super                                             River,25
# 4,3995 23rd     St,San Francisco,CA                        94114,USA,Ben's                                              Shop,10
# 5,1056 Sanchez  St,San Francisco,California,USA,Sanchez,12 NaN                                                             None
# 6,551  Alvarado St,San Francisco,CA                        94114,USA,Richvalley,20                                         None

# %%
from geopy.geocoders import ArcGIS
nom = ArcGIS()

# %%
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
nom.geocode('3995 23rd St San Francisco CA 94114')
# Out:
# Location(3995 23rd St, San Francisco, California, 94114, (37.752990821253434, -122.43170235858965, 0.0))

# %%
df1['adress_full'] = df1['Address'] + ', ' + df1['City'] + ', ' + df1['State'] + ', ' + df1['Country']

# %%
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees                                        adress_full
# 0          8         3666 21st St, San Francisco, CA 94114, USA
# 1         15       735 Dolores St, San Francisco, CA 94119, USA
# 2         25  332 Hill St, San Francisco, California 94114, USA
# 3         10         3995 23rd St, San Francisco, CA 94114, USA
# 4         12    1056 Sanchez St, San Francisco, California, USA
# ...

# %%
df1['location'] = df1.adress_full.apply(nom.geocode)

# %%
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees                                        adress_full  \
# 0          8         3666 21st St, San Francisco, CA 94114, USA
# 1         15       735 Dolores St, San Francisco, CA 94119, USA
# 2         25  332 Hill St, San Francisco, California 94114, USA
# 3         10         3995 23rd St, San Francisco, CA 94114, USA
# 4         12    1056 Sanchez St, San Francisco, California, USA
# ...
